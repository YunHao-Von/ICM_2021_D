# %%
import numpy as np
time=['1920-1950','1930-1960','1950-1970','1960-1980','1970-1990','1980-2000',
     '1990-2010','2000-2020']
max_degree=[32,212,327,237,170,99,40,7]
node_jieshu=[0.0,42.537,0.0,0.0,0.0,31,0.0,0.0]
edge_jieshu=[1.0,4.417,1.8,145.6,14.0,53,1.0,1.0]
density=[0.0199,0.01,0.007,0.0045,0.003,0.002,0.0015,0.003]
like_mean=[0.293,0.46,0.29,0.08,0.04,0.02,0.010,0.01]
partition=[12,12,9,11,14,17,21,33]

# %%
import numpy as np
he=sum(like_mean)
like_mean_1=np.array([like_mean])
gailv=like_mean_1/he
y=list((gailv*partition)[0])

# %%
import matplotlib.pyplot as plt
plt.plot(y,'r-')

# %%
import matplotlib.pyplot as plt
plt.figure(1,figsize=(10,10))
plt.plot(time,max_degree,'r-*',label='max_degree')
plt.legend()
plt.figure(2,figsize=(10,10))
plt.plot(time,node_jieshu,'r-*',label='node_jieshu')
plt.legend()
plt.figure(3,figsize=(10,10))
plt.plot(time,edge_jieshu,'r-*',label='edge_jieshu')
plt.legend()
plt.figure(4,figsize=(10,10))
plt.plot(time,density,'r-*',label='density')
plt.legend()
plt.figure(5,figsize=(10,10))
plt.plot(time,like_mean,'r-*',label='like_mean')
plt.legend()
plt.figure(6,figsize=(10,10))
plt.plot(time,partition,'r-*',label='partition')
plt.legend()
plt.show()

# %%
plt.figure(7,figsize=(10,10))
ax1=plt.subplot(2,3,1)
ax1.plot(max_degree,'r-*',label='max_degree')
ax1.legend()
ax1=plt.subplot(2,3,2)
ax1.plot(node_jieshu,'r-*',label='node_jieshu')
ax1.legend()
ax1=plt.subplot(2,3,3)
ax1.plot(density,'r-*',label='density')
ax1.legend()
ax1=plt.subplot(2,3,4)
ax1.plot(edge_jieshu,'r-*',label='edge_jieshu')
ax1.legend()
ax1=plt.subplot(2,3,5)
ax1.plot(like_mean,'r-*',label='like_mean')
ax1.legend()
ax1=plt.subplot(2,3,6)
ax1.plot(partition,'r-*',label='partition')
ax1.legend()
